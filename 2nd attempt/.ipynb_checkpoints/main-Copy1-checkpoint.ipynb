# %%
import json_lines
from langdetect import detect
from langdetect import detect_langs
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from sklearn.neural_network import MLPClassifier
import numpy as np

from sklearn.datasets import load_iris
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

lemmatizer = WordNetLemmatizer()
REMOVEABLE_CHARS = "»<>123456789\/&()?:!.,;'´"
ALL_TAGS = ['CC', 'CD', 'DT', 'EX', 'FW', 'IN', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'NN', 'NNS', 'NNP', 'NNPS', 'PDT',
 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'TO', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP',
 'WP$', 'WRB']
ACCEPTABLE_TAGS = ['CC', 'DT', 'EX', 'FW', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'PDT',
 'POS', 'PRP', 'PRP$', 'RP', 'TO', 'UH', 'VBD', 'VBG', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB']
MAX_FEATURES = 500
MIN_ENGLISH = 0.9999
LIMIT_INPUT_ROWS = 5000 # to stop run times hindering development (making this < 500 usually makes the graph angry)

def get_wordnet_pos(tag): # Return a char, based on input tag, that is used as a param in lemmatisation for enhanced results
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''

# %%
# READ IN INFO
reviews= []; polarity= []; are_early= [];
with open ('reviews.json', 'rb') as f:
    for i, item in enumerate(json_lines.reader(f)):
        if i <= LIMIT_INPUT_ROWS:
            try:
                langs = detect_langs(item['text'])
            except:
                pass
            for i, lang in enumerate(langs):
                if str(lang)[0:2] == 'en':
                    if float(str(lang)[3:]) > MIN_ENGLISH:
                        reviews.append(item['text'])
                        polarity.append(item['voted_up'])
                        are_early.append(item['early_access'])

# %%
# FILTER TEXT
for i, text in enumerate(reviews):
    text_words = nltk.word_tokenize(text.lower())
    tags = nltk.pos_tag(text_words)
    #print(tags)
    new_text= [];
    for j, word in enumerate(text_words):
        for char in word:
            if char in REMOVEABLE_CHARS:
                break
        else:
            wordnet_pos = get_wordnet_pos(tags[j][1])
            if wordnet_pos != '':
                new_text.append(lemmatizer.lemmatize(word, wordnet_pos))
            continue
    reviews[i] = new_text

for i, text in enumerate(reviews): 
    new_text= [];
    tags = nltk.pos_tag(reviews[i])
    for j, word in enumerate(text):
        if tags[j][1] in ACCEPTABLE_TAGS:
            new_text.append(word)
    reviews[i] = new_text
    #print(tags)

# %%
# MOST FREQ WORDS AS FEATURES
word_counts = {};
for text in reviews:
    for word in text:
        if word in word_counts:
            word_counts[word]+= 1
        else:
            word_counts[word]= 1
word_counts = {k: v for k, v in sorted(word_counts.items(), key=lambda item: item[1], reverse=True)}
trimd_word_counts = {}
if len(word_counts) > MAX_FEATURES:
    for i, entry in enumerate(word_counts):
        if i >= MAX_FEATURES:
            break
        trimd_word_counts[entry] = word_counts[entry]
word_counts = trimd_word_counts

tags = nltk.pos_tag(word_counts.keys()); # this part is just for the below print statement
for i, word in enumerate(word_counts):
    print("word: ", word, "| tag: ", tags[i][1], "| count: ",word_counts[word],"\n")
# Out:
# word:  i | tag:  RB | count:  884
#
# word:  good | tag:  JJ | count:  515
#
# word:  bad | tag:  JJ | count:  261
#
# word:  great | tag:  JJ | count:  243
#
# word:  other | tag:  JJ | count:  239
#
# word:  new | tag:  JJ | count:  220
#
# word:  much | tag:  JJ | count:  206
#
# word:  up | tag:  IN | count:  202
#
# word:  more | tag:  JJR | count:  181
#
# word:  out | tag:  IN | count:  169
#
# word:  many | tag:  JJ | count:  160
#
# word:  best | tag:  JJS | count:  145
#
# word:  same | tag:  JJ | count:  136
#
# word:  graphic | tag:  JJ | count:  128
#
# word:  hard | tag:  JJ | count:  125
#
# word:  free | tag:  JJ | count:  124
#
# word:  few | tag:  JJ | count:  119
#
# word:  fun | tag:  NN | count:  118
#
# word:  first | tag:  RB | count:  116
#
# word:  nice | tag:  JJ | count:  113
#
# word:  big | tag:  JJ | count:  105
#
# word:  different | tag:  JJ | count:  94
#
# word:  full | tag:  JJ | count:  86
#
# word:  old | tag:  JJ | count:  85
#
# word:  last | tag:  JJ | count:  83
#
# word:  little | tag:  JJ | count:  81
#
# word:  short | tag:  JJ | count:  80
#
# word:  give | tag:  NN | count:  78
#
# word:  easy | tag:  JJ | count:  78
#
# word:  down | tag:  RB | count:  77
#
# word:  update | tag:  RB | count:  76
#
# word:  high | tag:  JJ | count:  74
#
# word:  amazing | tag:  VBG | count:  70
#
# word:  such | tag:  JJ | count:  70
#
# word:  complete | tag:  JJ | count:  70
#
# word:  own | tag:  JJ | count:  69
#
# word:  most | tag:  JJS | count:  69
#
# word:  overall | tag:  JJ | count:  68
#
# word:  u | tag:  JJ | count:  67
#
# word:  real | tag:  JJ | count:  66
#
# word:  sure | tag:  JJ | count:  62
#
# word:  able | tag:  JJ | count:  61
#
# word:  worth | tag:  JJ | count:  59
#
# word:  original | tag:  JJ | count:  57
#
# word:  interesting | tag:  NN | count:  56
#
# word:  long | tag:  RB | count:  56
#
# word:  single | tag:  JJ | count:  56
#
# word:  off | tag:  RP | count:  55
#
# word:  fix | tag:  JJ | count:  55
#
# word:  enough | tag:  RB | count:  54
#
# word:  early | tag:  JJ | count:  53
#
# word:  boring | tag:  NN | count:  53
#
# word:  put | tag:  VBD | count:  52
#
# word:  quest | tag:  JJS | count:  51
#
# word:  main | tag:  JJ | count:  50
#
# word:  whole | tag:  JJ | count:  50
#
# word:  least | tag:  JJS | count:  48
#
# word:  next | tag:  JJ | count:  48
#
# word:  decent | tag:  NN | count:  47
#
# word:  open | tag:  JJ | count:  46
#
# word:  need | tag:  VBP | count:  46
#
# word:  low | tag:  JJ | count:  46
#
# word:  small | tag:  JJ | count:  44
#
# word:  cool | tag:  NN | count:  44
#
# word:  mechanic | tag:  JJ | count:  43
#
# word:  enjoyable | tag:  JJ | count:  42
#
# word:  â™¥â™¥â™¥â™¥ | tag:  NN | count:  42
#
# word:  terrible | tag:  JJ | count:  42
#
# word:  dead | tag:  JJ | count:  41
#
# word:  right | tag:  JJ | count:  41
#
# word:  second | tag:  JJ | count:  41
#
# word:  awesome | tag:  JJ | count:  41
#
# word:  upgrade | tag:  JJ | count:  39
#
# word:  finish | tag:  NN | count:  39
#
# word:  perfect | tag:  JJ | count:  38
#
# word:  pro | tag:  JJ | count:  37
#
# word:  huge | tag:  JJ | count:  36
#
# word:  want | tag:  NN | count:  36
#
# word:  due | tag:  JJ | count:  36
#
# word:  beautiful | tag:  JJ | count:  35
#
# word:  dont | tag:  NN | count:  35
#
# word:  repetitive | tag:  JJ | count:  35
#
# word:  unique | tag:  JJ | count:  34
#
# word:  special | tag:  JJ | count:  34
#
# word:  setting | tag:  VBG | count:  33
#
# word:  certain | tag:  JJ | count:  33
#
# word:  simple | tag:  JJ | count:  33
#
# word:  top | tag:  NN | count:  32
#
# word:  there | tag:  EX | count:  32
#
# word:  actual | tag:  JJ | count:  32
#
# word:  wrong | tag:  JJ | count:  32
#
# word:  negative | tag:  JJ | count:  31
#
# word:  felt | tag:  VBD | count:  31
#
# word:  poor | tag:  JJ | count:  31
#
# word:  unplayable | tag:  JJ | count:  31
#
# word:  fps | tag:  NN | count:  30
#
# word:  pretty | tag:  RB | count:  30
#
# word:  sound | tag:  JJ | count:  30
#
# word:  less | tag:  JJR | count:  30
#
# word:  + | tag:  JJ | count:  30
#
# word:  content | tag:  NN | count:  30
#
# word:  annoy | tag:  NN | count:  30
#
# word:  key | tag:  JJ | count:  29
#
# word:  final | tag:  JJ | count:  29
#
# word:  wish | tag:  NN | count:  29
#
# word:  use | tag:  NN | count:  28
#
# word:  super | tag:  JJ | count:  28
#
# word:  tutorial | tag:  JJ | count:  28
#
# word:  clear | tag:  JJ | count:  28
#
# word:  recommend | tag:  NN | count:  27
#
# word:  fine | tag:  NN | count:  27
#
# word:  available | tag:  JJ | count:  27
#
# word:  entire | tag:  JJ | count:  27
#
# word:  difficult | tag:  JJ | count:  27
#
# word:  cant | tag:  NN | count:  27
#
# word:  realistic | tag:  JJ | count:  26
#
# word:  launch | tag:  NN | count:  26
#
# word:  dlc | tag:  NN | count:  26
#
# word:  possible | tag:  JJ | count:  26
#
# word:  hit | tag:  NN | count:  26
#
# word:  die | tag:  NNS | count:  26
#
# word:  positive | tag:  JJ | count:  26
#
# word:  start | tag:  VBP | count:  25
#
# word:  minute | tag:  NN | count:  25
#
# word:  stick | tag:  JJ | count:  25
#
# word:  large | tag:  JJ | count:  25
#
# word:  awful | tag:  JJ | count:  25
#
# word:  several | tag:  JJ | count:  24
#
# word:  come | tag:  VBN | count:  24
#
# word:  do | tag:  VBP | count:  23
#
# word:  close | tag:  RB | count:  23
#
# word:  add | tag:  VB | count:  23
#
# word:  achievement | tag:  JJ | count:  23
#
# word:  total | tag:  JJ | count:  23
#
# word:  mean | tag:  JJ | count:  23
#
# word:  black | tag:  JJ | count:  23
#
# word:  strong | tag:  JJ | count:  22
#
# word:  play | tag:  NN | count:  22
#
# word:  current | tag:  JJ | count:  22
#
# word:  funny | tag:  JJ | count:  22
#
# word:  extra | tag:  JJ | count:  22
#
# word:  slow | tag:  JJ | count:  22
#
# word:  â™¥â™¥â™¥â™¥â™¥â™¥â™¥ | tag:  NN | count:  21
#
# word:  fight | tag:  NN | count:  21
#
# word:  quick | tag:  JJ | count:  21
#
# word:  wait | tag:  NN | count:  21
#
# word:  write | tag:  NN | count:  21
#
# word:  enemy | tag:  NN | count:  20
#
# word:  * | tag:  NNP | count:  20
#
# word:  screen | tag:  JJ | count:  20
#
# word:  weird | tag:  JJ | count:  20
#
# word:  make | tag:  NN | count:  20
#
# word:  enjoy | tag:  NN | count:  20
#
# word:  major | tag:  JJ | count:  20
#
# word:  playable | tag:  JJ | count:  20
#
# word:  fantastic | tag:  JJ | count:  20
#
# word:  ive | tag:  NN | count:  20
#
# word:  back | tag:  RB | count:  20
#
# word:  miss | tag:  JJ | count:  20
#
# word:  potential | tag:  NN | count:  20
#
# word:  map | tag:  NN | count:  19
#
# word:  frustrating | tag:  VBG | count:  19
#
# word:  red | tag:  JJ | count:  19
#
# word:  happy | tag:  JJ | count:  19
#
# word:  toxic | tag:  NN | count:  19
#
# word:  object | tag:  VBP | count:  19
#
# word:  sad | tag:  JJ | count:  19
#
# word:  broken | tag:  JJ | count:  19
#
# word:  classic | tag:  JJ | count:  18
#
# word:  excellent | tag:  NN | count:  18
#
# word:  physic | tag:  JJ | count:  18
#
# word:  similar | tag:  JJ | count:  18
#
# word:  level | tag:  NN | count:  18
#
# word:  random | tag:  NN | count:  18
#
# word:  in-game | tag:  JJ | count:  18
#
# word:  happen | tag:  NN | count:  18
#
# word:  server | tag:  NN | count:  18
#
# word:  horrible | tag:  JJ | count:  17
#
# word:  human | tag:  JJ | count:  17
#
# word:  normal | tag:  JJ | count:  17
#
# word:  future | tag:  NN | count:  17
#
# word:  casual | tag:  JJ | count:  17
#
# word:  russian | tag:  JJ | count:  17
#
# word:  empty | tag:  JJ | count:  17
#
# word:  favorite | tag:  JJ | count:  17
#
# word:  stupid | tag:  JJ | count:  17
#
# word:  devs | tag:  NN | count:  17
#
# word:  lose | tag:  VBP | count:  16
#
# word:  basic | tag:  JJ | count:  16
#
# word:  love | tag:  NN | count:  16
#
# word:  stop | tag:  NN | count:  16
#
# word:  fast | tag:  NN | count:  16
#
# word:  building | tag:  NN | count:  16
#
# word:  ready | tag:  JJ | count:  16
#
# word:  click | tag:  NN | count:  16
#
# word:  saw | tag:  VBD | count:  16
#
# word:  bug | tag:  JJ | count:  16
#
# word:  minor | tag:  JJ | count:  15
#
# word:  serious | tag:  JJ | count:  15
#
# word:  ping | tag:  VBG | count:  15
#
# word:  friend | tag:  NN | count:  15
#
# word:  playing | tag:  VBG | count:  15
#
# word:  break | tag:  JJ | count:  15
#
# word:  suck | tag:  JJ | count:  15
#
# word:  character | tag:  NN | count:  15
#
# word:  mod | tag:  NN | count:  15
#
# word:  visual | tag:  JJ | count:  15
#
# word:  ok | tag:  NN | count:  15
#
# word:  itâ€™s | tag:  JJ | count:  15
#
# word:  useless | tag:  JJ | count:  15
#
# word:  late | tag:  JJ | count:  14
#
# word:  mode | tag:  NN | count:  14
#
# word:  feeling | tag:  NN | count:  14
#
# word:  interested | tag:  JJ | count:  14
#
# word:  writing | tag:  VBG | count:  14
#
# word:  general | tag:  JJ | count:  14
#
# word:  fan | tag:  NN | count:  14
#
# word:  true | tag:  JJ | count:  14
#
# word:  build | tag:  NN | count:  14
#
# word:  crash | tag:  NN | count:  14
#
# word:  massive | tag:  JJ | count:  14
#
# word:  fair | tag:  JJ | count:  14
#
# word:  online | tag:  JJ | count:  14
#
# word:  average | tag:  JJ | count:  14
#
# word:  survival | tag:  JJ | count:  14
#
# word:  constant | tag:  JJ | count:  14
#
# word:  dark | tag:  NN | count:  14
#
# word:  only | tag:  RB | count:  14
#
# word:  impossible | tag:  JJ | count:  14
#
# word:  co-op | tag:  JJ | count:  13
#
# word:  cheap | tag:  JJ | count:  13
#
# word:  absolute | tag:  NN | count:  13
#
# word:  keep | tag:  VB | count:  13
#
# word:  unlock | tag:  NN | count:  13
#
# word:  weapon | tag:  NN | count:  13
#
# word:  suppose | tag:  VBD | count:  13
#
# word:  puzzle | tag:  JJ | count:  13
#
# word:  avoid | tag:  JJ | count:  13
#
# word:  hear | tag:  NN | count:  13
#
# word:  fresh | tag:  JJ | count:  13
#
# word:  dumb | tag:  JJ | count:  13
#
# word:  ur | tag:  JJ | count:  13
#
# word:  etc | tag:  NN | count:  13
#
# word:  create | tag:  VBP | count:  13
#
# word:  previous | tag:  JJ | count:  13
#
# word:  expensive | tag:  JJ | count:  13
#
# word:  point | tag:  NN | count:  13
#
# word:  developer | tag:  NN | count:  13
#
# word:  matchmaking | tag:  VBG | count:  13
#
# word:  â™¥â™¥â™¥â™¥â™¥â™¥ | tag:  JJ | count:  13
#
# word:  shoot | tag:  NN | count:  12
#
# word:  obvious | tag:  JJ | count:  12
#
# word:  solid | tag:  JJ | count:  12
#
# word:  multiplayer | tag:  NN | count:  12
#
# word:  half | tag:  NN | count:  12
#
# word:  bring | tag:  VBG | count:  12
#
# word:  survive | tag:  JJ | count:  12
#
# word:  addictive | tag:  JJ | count:  12
#
# word:  creative | tag:  JJ | count:  12
#
# word:  immersive | tag:  JJ | count:  12
#
# word:  let | tag:  NN | count:  12
#
# word:  third | tag:  JJ | count:  12
#
# word:  okay | tag:  JJ | count:  12
#
# word:  female | tag:  NN | count:  12
#
# word:  important | tag:  JJ | count:  12
#
# word:  multiple | tag:  JJ | count:  12
#
# word:  read | tag:  JJ | count:  12
#
# word:  alive | tag:  JJ | count:  12
#
# word:  scary | tag:  JJ | count:  12
#
# word:  f | tag:  NN | count:  12
#
# word:  type | tag:  NN | count:  12
#
# word:  trash | tag:  NN | count:  12
#
# word:  buggy | tag:  NN | count:  11
#
# word:  neat | tag:  NN | count:  11
#
# word:  guy | tag:  NN | count:  11
#
# word:  particular | tag:  JJ | count:  11
#
# word:  mobile | tag:  NN | count:  11
#
# word:  specific | tag:  JJ | count:  11
#
# word:  base | tag:  NN | count:  11
#
# word:  annoying | tag:  VBG | count:  11
#
# word:  choose | tag:  JJ | count:  11
#
# word:  instal | tag:  JJ | count:  11
#
# word:  double | tag:  NN | count:  11
#
# word:  know | tag:  VBP | count:  11
#
# word:  objective | tag:  JJ | count:  11
#
# word:  deep | tag:  JJ | count:  11
#
# word:  away | tag:  RB | count:  11
#
# word:  various | tag:  JJ | count:  11
#
# word:  technical | tag:  JJ | count:  11
#
# word:  â˜ | tag:  NNS | count:  11
#
# word:  take | tag:  VBP | count:  11
#
# word:  call | tag:  NN | count:  11
#
# word:  aspect | tag:  NN | count:  10
#
# word:  secret | tag:  JJ | count:  10
#
# word:  active | tag:  JJ | count:  10
#
# word:  acting | tag:  VBG | count:  10
#
# word:  atmospheric | tag:  JJ | count:  10
#
# word:  english | tag:  JJ | count:  10
#
# word:  willing | tag:  JJ | count:  10
#
# word:  skill | tag:  NN | count:  10
#
# word:  present | tag:  JJ | count:  10
# word:  regular | tag:  JJ | count:  10
#
# word:  sick | tag:  JJ | count:  10
#
# word:  heavy | tag:  JJ | count:  10
#
# word:  bit | tag:  NN | count:  10
#
# word:  spent | tag:  JJ | count:  10
#
# word:  fit | tag:  JJ | count:  10
#
# word:  hidden | tag:  NN | count:  10
#
# word:  young | tag:  JJ | count:  10
#
# word:  thought | tag:  VBN | count:  10
#
# word:  gameplay | tag:  JJ | count:  10
#
# word:  side | tag:  NN | count:  10
#
# word:  sci-fi | tag:  JJ | count:  10
#
# word:  personal | tag:  JJ | count:  10
#
# word:  straight | tag:  NN | count:  10
#
# word:  bunch | tag:  NN | count:  10
#
# word:  light | tag:  NN | count:  10
#
# word:  grind | tag:  NN | count:  10
#
# word:  expect | tag:  VBP | count:  10
#
# word:  tedious | tag:  JJ | count:  10
#
# word:  arcade | tag:  JJ | count:  10
#
# word:  live | tag:  JJ | count:  10
#
# word:  ask | tag:  NN | count:  10
#
# word:  past | tag:  IN | count:  10
#
# word:  disappointed | tag:  JJ | count:  10
#
# word:  amaze | tag:  NN | count:  9
#
# word:  beat | tag:  JJ | count:  9
#
# word:  end | tag:  JJ | count:  9
#
# word:  smart | tag:  NN | count:  9
#
# word:  like | tag:  IN | count:  9
#
# word:  strange | tag:  JJ | count:  9
#
# word:  beta | tag:  NN | count:  9
#
# word:  wonderful | tag:  JJ | count:  9
#
# word:  cosmetic | tag:  JJ | count:  9
#
# word:  god | tag:  NN | count:  9
#
# word:  infinite | tag:  JJ | count:  9
#
# word:  individual | tag:  JJ | count:  9
#
# word:  modern | tag:  JJ | count:  9
#
# word:  logic | tag:  JJ | count:  9
#
# word:  grindy | tag:  NN | count:  9
#
# word:  drive | tag:  NN | count:  9
#
# word:  either | tag:  CC | count:  9
#
# word:  interactive | tag:  JJ | count:  9
#
# word:  standard | tag:  NN | count:  9
#
# word:  following | tag:  VBG | count:  9
#
# word:  force | tag:  NN | count:  9
#
# word:  mess | tag:  NN | count:  9
#
# word:  have | tag:  VBP | count:  9
#
# word:  kill | tag:  VBN | count:  9
#
# word:  ban | tag:  JJ | count:  9
#
# word:  walking | tag:  VBG | count:  9
#
# word:  disappointing | tag:  JJ | count:  9
#
# word:  loading | tag:  NN | count:  9
#
# word:  uninstalled | tag:  JJ | count:  9
#
# word:  mid | tag:  NN | count:  9
#
# word:  friendly | tag:  JJ | count:  8
#
# word:  drop | tag:  NN | count:  8
#
# word:  powerful | tag:  JJ | count:  8
#
# word:  learn | tag:  JJ | count:  8
#
# word:  shot | tag:  NN | count:  8
#
# word:  load | tag:  NN | count:  8
#
# word:  ta | tag:  NN | count:  8
#
# word:  cry | tag:  NN | count:  8
#
# word:  destroy | tag:  NN | count:  8
#
# word:  mad | tag:  JJ | count:  8
#
# word:  im | tag:  JJ | count:  8
#
# word:  usual | tag:  JJ | count:  8
#
# word:  s | tag:  NN | count:  8
#
# word:  ea | tag:  JJ | count:  8
#
# word:  military | tag:  JJ | count:  8
#
# word:  unable | tag:  JJ | count:  8
#
# word:  depth | tag:  NN | count:  8
#
# word:  steal | tag:  NN | count:  8
#
# word:  seem | tag:  VBP | count:  8
#
# word:  lead | tag:  JJ | count:  8
#
# word:  disable | tag:  JJ | count:  8
#
# word:  review | tag:  NN | count:  8
#
# word:  appeal | tag:  NN | count:  8
#
# word:  alien | tag:  JJ | count:  8
#
# word:  sorry | tag:  NN | count:  8
#
# word:  endless | tag:  RBR | count:  8
#
# word:  incredible | tag:  JJ | count:  8
#
# word:  spend | tag:  NN | count:  8
#
# word:  refund | tag:  NN | count:  8
#
# word:  plenty | tag:  NN | count:  8
#
# word:  ridiculous | tag:  JJ | count:  8
#
# word:  fail | tag:  JJ | count:  8
#
# word:  con | tag:  NN | count:  8
#
# word:  audio | tag:  NN | count:  8
#
# word:  beginning | tag:  VBG | count:  8
#
# word:  rare | tag:  JJ | count:  8
#
# word:  couple | tag:  NN | count:  8
#
# word:  left | tag:  VBD | count:  8
#
# word:  leave | tag:  RBR | count:  8
#
# word:  humble | tag:  JJ | count:  8
#
# word:  skin | tag:  NN | count:  8
#
# word:  win | tag:  NN | count:  8
#
# word:  safe | tag:  JJ | count:  8
#
# word:  design | tag:  NN | count:  8
#
# word:  frustrate | tag:  NN | count:  8
#
# word:  pointless | tag:  NN | count:  8
#
# word:  mediocre | tag:  NN | count:  8
#
# word:  allow | tag:  IN | count:  8
#
# word:  clunky | tag:  NN | count:  8
#
# word:  ruin | tag:  NN | count:  8
#
# word:  optimize | tag:  VB | count:  7
#
# word:  detailed | tag:  JJ | count:  7
#
# word:  bother | tag:  NN | count:  7
#
# word:  chat | tag:  NN | count:  7
#
# word:  alright | tag:  VBD | count:  7
#
# word:  gear | tag:  JJ | count:  7
#
# word:  common | tag:  JJ | count:  7
#
# word:  giant | tag:  JJ | count:  7
#
# word:  crazy | tag:  NN | count:  7
#
# word:  indie | tag:  NN | count:  7
#
# word:  follow | tag:  VBP | count:  7
#
# word:  narrative | tag:  JJ | count:  7
#
# word:  send | tag:  NN | count:  7
#
# word:  max | tag:  NN | count:  7
#
# word:  ending | tag:  VBG | count:  7
#
# word:  competitive | tag:  JJ | count:  7
#
# word:  decide | tag:  NN | count:  7
#
# word:  solo | tag:  NN | count:  7
#
# word:  smooth | tag:  JJ | count:  7
#
# word:  social | tag:  JJ | count:  7
#
# word:  please | tag:  NN | count:  7
#
# word:  weak | tag:  JJ | count:  7
#
# word:  around | tag:  IN | count:  7
#
# word:  purpose | tag:  JJ | count:  7
#
# word:  generic | tag:  JJ | count:  7
#
# word:  save | tag:  VBP | count:  7
#
# word:  become | tag:  VBN | count:  7
#
# word:  lot | tag:  NN | count:  7
#
# word:  loot | tag:  NN | count:  7
#
# word:  rpg | tag:  VB | count:  7
#
# word:  likely | tag:  JJ | count:  7
#
# word:  public | tag:  JJ | count:  7
#
# word:  wild | tag:  WP | count:  7
#
# word:  damn | tag:  VBP | count:  7
#
# word:  crafting | tag:  VBG | count:  7
#
# word:  delete | tag:  JJ | count:  7
#
# word:  chase | tag:  NN | count:  7
#
# word:  painful | tag:  JJ | count:  7
#
# word:  insane | tag:  NN | count:  7
#
# word:  stable | tag:  JJ | count:  7
#
# word:  tactical | tag:  JJ | count:  7
#
# word:  limited | tag:  VBD | count:  7
#
# word:  quiet | tag:  JJ | count:  7
#
# word:  collect | tag:  JJ | count:  7
#
# word:  honest | tag:  JJS | count:  7
#
# word:  fortnite | tag:  JJ | count:  7
#
# word:  private | tag:  JJ | count:  7
#
# word:  progress | tag:  NN | count:  7
#
# word:  portal | tag:  NN | count:  7
#
# word:  hat | tag:  WP | count:  7
#
# word:  speak | tag:  JJ | count:  7
#
# word:  german | tag:  JJ | count:  7
#
# word:  exact | tag:  JJ | count:  7
#
# word:  modding | tag:  VBG | count:  7
#
# word:  loud | tag:  JJ | count:  7
#
# word:  uninteresting | tag:  JJ | count:  7
#
# word:  cheater | tag:  NN | count:  7
#
# word:  t | tag:  NN | count:  6
#
# word:  hundred | tag:  VBD | count:  6
#
# word:  racing | tag:  VBG | count:  6
#
# word:  arm | tag:  NN | count:  6
#
# word:  match | tag:  NN | count:  6
#
# word:  title | tag:  NN | count:  6
#
# word:  additional | tag:  JJ | count:  6
#
# word:  girl | tag:  NN | count:  6
#
# word:  cod | tag:  NN | count:  6
#
# word:  tough | tag:  JJ | count:  6
#
# word:  find | tag:  NN | count:  6
#
# word:  clean | tag:  JJ | count:  6
#
# word:  throw | tag:  NN | count:  6
#
# word:  genre | tag:  NN | count:  6
#
# word:  storyline | tag:  NN | count:  6
#
# word:  over | tag:  IN | count:  6
#
# word:  cute | tag:  JJ | count:  6
#
# word:  touch | tag:  JJ | count:  6
#
# word:  shallow | tag:  NN | count:  6
#
# word:  handle | tag:  NN | count:  6
#
# word:  wide | tag:  JJ | count:  6
#
# word:  flashlight | tag:  VBD | count:  6
#
# word:  legendary | tag:  JJ | count:  6
#
# word:  destiny | tag:  JJ | count:  6
#
# word:  physical | tag:  JJ | count:  6
#
# word:  brilliant | tag:  NN | count:  6
#
# word:  tiny | tag:  JJ | count:  6
#
# word:  welcome | tag:  JJ | count:  6
#
# word:  grab | tag:  NN | count:  6
#
# word:  offensive | tag:  JJ | count:  6
#
# word:  gun | tag:  NN | count:  6
#
# word:  planet | tag:  NN | count:  6
#
# word:  quit | tag:  NN | count:  6
#
# word:  affect | tag:  VBP | count:  6
#
# word:  busy | tag:  JJ | count:  6
#
# word:  notice | tag:  RB | count:  6
#
# word:  disappoint | tag:  NN | count:  6
#
# word:  detective | tag:  NN | count:  6

# %%
# CREATE 1-HOT ENCODINGS
one_hots = [];
for text in reviews:
    one_hot = [];
    for i in range(MAX_FEATURES):
        one_hot.append(0)
    for word in text:
        if word in word_counts:
            one_hot[list(word_counts).index(word)]+= 1
    one_hots.append(one_hot)

for i, one_hot in enumerate(one_hots): # convert array of lists into 2d array
    one_hot_arr = np.array(one_hot)
    one_hots[i] = one_hot_arr
one_hots = np.array(one_hots)

# %%
# TRAIN, PREDICT, GRAPH
X_train, X_test, y_train, y_test = train_test_split(one_hots, polarity, random_state=1, test_size=0.2) # change the second param here to switch between polarity and early_access
sc_X = StandardScaler()
X_train_scaled = sc_X.fit_transform(X_train)
X_test_scaled = sc_X.transform(X_test)

clf = MLPClassifier(hidden_layer_sizes=(256,128,64,32), activation="relu", random_state=1).fit(X_train_scaled, y_train)
y_pred=clf.predict(X_test_scaled)
print("overall accuracy: ",clf.score(X_test_scaled, y_test))

fig=plot_confusion_matrix(clf, X_test_scaled, y_test)
fig.figure_.suptitle("Confusion Matrix")
plt.show()
# Out:
# overall accuracy:  0.6368421052631579
